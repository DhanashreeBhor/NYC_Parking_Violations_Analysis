# %%
import pandas as pd
df = pd.read_csv("https://azdac24we.blob.core.windows.net/silver/raw/ml/part-00000-tid-4926575201596170249-392ac987-9333-4873-8e43-f28eddec48b0-675-1-c000.csv",low_memory = False)

# %%
df.head()
# Out:
#    summons_number plate_id registration_state plate_type  issue_date  \
# 0      1476932062  KBR4498                 NY        PAS  07/06/2023
# 1      1485793567  HSL9583                 NY        PAS  07/01/2023
# 2      1488929816  HZM6922                 NY        OMT  06/22/2023
# 3      1489610030  MDY2223                 PA        PAS  06/30/2023
# 4      1491319100   H16985                 NY        PAS  06/13/2023
#
#    violation_code vehicle_body_type vehicle_make  issuer_precinct  \
# 0              14              SUBN         JEEP                0
# 1              40               SDN        ME/BE              122
# 2              14              SUBN        LEXUS              105
# 3              17               SDN        ME/BE                0
# 4              98              SUBN        TOYOT               68
#
#    issuer_code violation_county  violation_hour  violation_minutes
# 0       355553                K              22                 57
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Assuming 'df' is your pandas DataFrame

columns_to_encode = ['registration_state', 'plate_type', 'violation_code',
                     'vehicle_body_type', 'vehicle_make', 'issuer_precinct',
                     'issuer_code', 'violation_county', 'violation_hour',
                     'violation_minutes']

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Encode each column
for column in columns_to_encode:
    df[column] = label_encoder.fit_transform(df[column])

# Display the modified DataFrame
df.head()
# Out:
#    summons_number plate_id  registration_state  plate_type  issue_date  \
# 0      1476932062  KBR4498                  45          58  07/06/2023
# 1      1485793567  HSL9583                  45          58  07/01/2023
# 2      1488929816  HZM6922                  45          53  06/22/2023
# 3      1489610030  MDY2223                  50          58  06/30/2023
# 4      1491319100   H16985                  45          58  06/13/2023
#
#    violation_code  vehicle_body_type  vehicle_make  issuer_precinct  \
# 0              13                745          1100                0
# 1              39                704          1440              119
# 2              13                745          1283              102
# 3              16                704          1440                0
# 4              97                745          2227               65
#
#    issuer_code  violation_county  violation_hour  violation_minutes
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Assuming df is your DataFrame containing the data
# df = ...

# Select features and target variable
features = ['registration_state', 'plate_type', 'violation_code', 'vehicle_body_type',
            'vehicle_make', 'issuer_precinct', 'issuer_code', 'violation_county',
            'violation_hour', 'violation_minutes']
target = 'violation_code'  # Replace 'target_variable' with the name of your target variable

# Encode categorical variables (label encoding)
encoder = LabelEncoder()
df_encoded = df[features].apply(encoder.fit_transform)

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(df_encoded, df[target], test_size=0.2, random_state=42)

# Create KNN model
k = 5  # number of neighbors
knn = KNeighborsClassifier(n_neighbors=k)

# Train the model
knn.fit(X_train, y_train)

# Make predictions on the test set
predictions = knn.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7099409132305758

# %%
from sklearn.metrics import classification_report

class_report = classification_report(y_test, predictions)
print("Classification Report:")
print(class_report)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn.metrics import confusion_matrix

conf_matrix = confusion_matrix(y_test, predictions)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[   8    1    3 ...    0    0    0]
#  [   1    0    0 ...    0    0    0]
#  [   5    0    4 ...    0    0    0]
#  ...
#  [   0    0    0 ...    0    5    0]
#  [   0    0    0 ...    0 3598    7]
#  [   0    0    0 ...    0  121   59]]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Assuming df is your DataFrame containing the data
# df = ...

# Select features and target variable
features = ['registration_state', 'plate_type', 'violation_code', 'vehicle_body_type',
            'vehicle_make', 'issuer_precinct', 'issuer_code', 'violation_county',
            'violation_hour', 'violation_minutes']
target = 'violation_code'  # Replace 'target_variable' with the name of your target variable

# Encode categorical variables (label encoding)
encoder = LabelEncoder()
df_encoded = df[features].apply(encoder.fit_transform)

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(df_encoded, df['violation_code'], test_size=0.2, random_state=42)

# Create SVM model
svm_model = SVC()

# Train the model
svm_model.fit(X_train, y_train)

# Make predictions on the test set
predictions = svm_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)
